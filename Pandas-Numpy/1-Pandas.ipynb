# %% [markdown]
# <center><img src="http://pandas.pydata.org/_static/pandas_logo.png" height="500"/></center>
#
# <center><img src="http://radhakrishna.typepad.com/.a/6a00d83453b94569e2016303990926970d-pi" height="500"/></center>

# %% [markdown]
# ----
# Background
# -----
#
#
# The pandas python library was developed by Wes McKinney at a quant hedge fund and later open sourced.
#
# Wes McKinney:
#
# > I had a distinct set of requirements that were not well-addressed by any single tool at my disposal:
#
# > I wanted to be able to do all of things in one place, preferably in a language well-suited to general purpose software development.

# %% [markdown]
# By The End Of This Session You Should Be Able To:
# ----
#
# - Explain why Pandas is important to Data Scientists
# - Use the common features of a DataFrame
#
# ----

# %% [markdown]
# Start with a clean namespace. It is a good habit to get into.

# %%
reset -fs

# %% [markdown]
# ---
# Installation
# ----
#
# You should have the most current Pandas installed but let's check...

# %%
import pandas as pd

# %% [markdown]
# We'll still need NumPy

# %%
import numpy as np

# %% [markdown]
# ---
# DataFrame, aka Excel on Steroids
# ----
#
# DataFrames are tables with labeled rows and columns. That is called tabular data.
#
# Let's make a DataFrame...

# %%
neighborhoods = ["Bayview", "Chinatown", "Excelsior", "Haight Ashbury"]
populations = [35890, 14540, 37960, 21800]

#list(zip(list1, list2)): combining the elements of two list to one list with tuples consisting of one element of each list.
sf = list(zip(neighborhoods, populations))

# creating an instance of the pandasclass "DataFrame"
df_sf = pd.DataFrame(data=sf, 
                     columns=["neighborhood", "population"])
df_sf
# Out:
#      neighborhood  population
# 0         Bayview       35890
# 1       Chinatown       14540
# 2       Excelsior       37960
# 3  Haight Ashbury       21800

# %% [markdown]
# Let's check out the methods...

# %%
# df_sf.<tab>

# %% [markdown]
# __Feature__: Tab Completion for column names

# %%
df_sf.population
# Out:
# 0    35890
# 1    14540
# 2    37960
# 3    21800
# Name: population, dtype: int64

# %% [markdown]
# What is that?

# %% [markdown]
# "Functional" approach to computation
#
# Chain methods together

# %%
# I don't think, that I like this presentation of attribute acces. It's easy to mix it up with common attributes 
df_sf.population.sum()
# Out:
# 110190

# %% [markdown]
# **Pandas is good at dealing with data that is:**
# - Tabular/Column data (e.g. csv files)
# - Time series
# - Medium data
#     - < 1 million rows
#     - < 5GB of data
#
# **Pandas is not good at dealing with data that is:**
# - Text / Image / Audio
# - Big data sets
#     - > 1 million rows
#     - > 10GB

# %% [markdown]
# <br>
# <br>
# <br>
#
# ----

# %% [markdown]
# Let's explore a dataset. Taking a trip under the sea...
#
# <center><img src="https://upload.wikimedia.org/wikipedia/commons/b/bc/Abalone_at_California_Academy_of_Sciences.JPG" height="500"/></center>

# %% [markdown]
# Reading a .csv (comma separated value) file.
#
# [Source](https://archive.ics.uci.edu/ml/datasets/Abalone)

# %%
pwd
# Out:
# '/Users/David/nf-sep-20/2020-ds-Pandas-Numpy'

# %%
df_abalone = pd.read_csv("data/abalone.csv")

# %%
df_abalone
# Out:
#      sex  length  diameter  height  weight_whole  weight_shucked  viscera  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245   0.1010
# 1      M   0.350     0.265   0.090        0.2255          0.0995   0.0485
# 2      F   0.530     0.420   0.135        0.6770          0.2565   0.1415
# 3      M   0.440     0.365   0.125        0.5160          0.2155   0.1140
# 4168   F   0.515     0.400   0.125        0.6150          0.2865   0.1230
# 4169   M   0.520     0.385   0.165        0.7910          0.3750   0.1800
# 4170   M   0.550     0.430   0.130        0.8395          0.3155   0.1955
# 4171   M   0.560     0.430   0.155        0.8675          0.4000   0.1720
# 4172   F   0.565     0.450   0.165        0.8870          0.3700   0.2390
# 4173   M   0.590     0.440   0.135        0.9660          0.4390   0.2145
# 4174   M   0.600     0.475   0.205        1.1760          0.5255   0.2875
# 4175   F   0.625     0.485   0.150        1.0945          0.5310   0.2610
# 4176   M   0.710     0.555   0.195        1.9485          0.9455   0.3765
#
#        shell  n_rings
# 0     0.1500       15
# 1     0.0700        7
# 2     0.2100        9
# 3     0.1550       10
# 4     0.0550        7
# 5     0.1200        8
# 6     0.3300       20
# 7     0.2600       16
# 8     0.1650        9
# 9     0.3200       19
# 10    0.2100       14
# 11    0.1350       10
# 12    0.1900       11
# 13    0.2050       10
# 14    0.1850       10
# 15    0.2400       12
# 16    0.1150        7
# 17    0.1300       10
# 18    0.1000        7
# 19    0.1150        9
# 20    0.0750       11
# 21    0.0850       10
# 22    0.2700       12
# 23    0.2000        9
# 24    0.3050       10
# 25    0.3000       11
# 26    0.2850       11
# 27    0.2800       12
# 28    0.2950       15
# 29    0.2000       11
# ...      ...      ...
# 4147  0.4450       11
# 4148  0.3550       11
# 4149  0.0300        6
# 4150  0.0460        7
# 4151  0.0410        6
# 4152  0.0615        7
# 4153  0.1100        8
# 4154  0.0885        6
# 4155  0.1150        6
# 4156  0.1460        8
# 4157  0.1550        8
# 4158  0.1400        8
# 4159  0.2590        9
# 4160  0.3000       11
# 4161  0.2845       11
# 4162  0.0920        8
# 4163  0.0790        7
# 4164  0.0810        7
# 4165  0.0880        7
# 4166  0.1560       10
# 4167  0.1535        9
# 4168  0.1765        8
# 4169  0.1815       10
# 4170  0.2405       10
# 4171  0.2290        8
# 4172  0.2490       11
# 4173  0.2605       10
# 4174  0.3080        9
# 4175  0.2960       10
# 4176  0.4950       12
#
# [4177 rows x 9 columns]

# %% [markdown]
# -----
# Exploratory Data Analysis (EDA)
# ----
#
# DataFrames are useful for Exploratory Data Analysis (EDA)

# %%
# used the "T" for transposition!
df_abalone.head().T # First 5 rows
# Out:
#                      0       1       2       3       4
# sex                  M       M       F       M       I
# length           0.455    0.35    0.53    0.44    0.33
# diameter         0.365   0.265    0.42   0.365   0.255
# height           0.095    0.09   0.135   0.125    0.08
# weight_whole     0.514  0.2255   0.677   0.516   0.205
# weight_shucked  0.2245  0.0995  0.2565  0.2155  0.0895
# viscera          0.101  0.0485  0.1415   0.114  0.0395
# shell             0.15    0.07    0.21   0.155   0.055
# n_rings             15       7       9      10       7

# %%
df_abalone.tail() # Last 5 rows
# Out:
#      sex  length  diameter  height  weight_whole  weight_shucked  viscera  \
# 4172   F   0.565     0.450   0.165        0.8870          0.3700   0.2390
# 4173   M   0.590     0.440   0.135        0.9660          0.4390   0.2145
# 4174   M   0.600     0.475   0.205        1.1760          0.5255   0.2875
# 4175   F   0.625     0.485   0.150        1.0945          0.5310   0.2610
# 4176   M   0.710     0.555   0.195        1.9485          0.9455   0.3765
#
#        shell  n_rings
# 4172  0.2490       11
# 4173  0.2605       10
# 4174  0.3080        9
# 4175  0.2960       10
# 4176  0.4950       12

# %%
df_abalone.tail(n=1)     # Protip: Just look at the last row
# Out:
#      sex  length  diameter  height  weight_whole  weight_shucked  viscera  \
# 4176   M    0.71     0.555   0.195        1.9485          0.9455   0.3765
#
#       shell  n_rings
# 4176  0.495       12

# %%
df_abalone.describe()  # Summarize data
# Out:
#             length     diameter       height  weight_whole  weight_shucked  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#            viscera        shell      n_rings
# count  4177.000000  4177.000000  4177.000000
# mean      0.180594     0.238831     9.933684
# std       0.109614     0.139203     3.224169
# min       0.000500     0.001500     1.000000
# 25%       0.093500     0.130000     8.000000
# 50%       0.171000     0.234000     9.000000
# 75%       0.253000     0.329000    11.000000
# max       0.760000     1.005000    29.000000

# %%
# rows, colums
df_abalone.shape
# Out:
# (4177, 9)

# %% [markdown]
# What is 4177? <br>
# What is 9?
# <details><summary>
# Click here for answer
# </summary>
# The number of rows and columns
# </details>

# %%
df_abalone.T           # Transpose data
# Out:
#                   0       1       2       3       4       5       6     \
# sex                  M       M       F       M       I       I       F
# length           0.455    0.35    0.53    0.44    0.33   0.425    0.53
# diameter         0.365   0.265    0.42   0.365   0.255     0.3   0.415
# height           0.095    0.09   0.135   0.125    0.08   0.095    0.15
# weight_whole     0.514  0.2255   0.677   0.516   0.205  0.3515  0.7775
# weight_shucked  0.2245  0.0995  0.2565  0.2155  0.0895   0.141   0.237
# viscera          0.101  0.0485  0.1415   0.114  0.0395  0.0775  0.1415
# shell             0.15    0.07    0.21   0.155   0.055    0.12    0.33
# n_rings             15       7       9      10       7       8      20
#
#                   7       8       9     ...    4167    4168    4169    4170  \
# sex                  F       M       F  ...       M       F       M       M
# length           0.545   0.475    0.55  ...     0.5   0.515    0.52    0.55
# diameter         0.425    0.37    0.44  ...    0.38     0.4   0.385    0.43
# height           0.125   0.125    0.15  ...   0.125   0.125   0.165    0.13
# weight_whole     0.768  0.5095  0.8945  ...   0.577   0.615   0.791  0.8395
# weight_shucked   0.294  0.2165  0.3145  ...   0.269  0.2865   0.375  0.3155
# viscera         0.1495  0.1125   0.151  ...  0.1265   0.123    0.18  0.1955
# shell             0.26   0.165    0.32  ...  0.1535  0.1765  0.1815  0.2405
# n_rings             16       9      19  ...       9       8      10      10
#
#                   4171   4172    4173    4174    4175    4176
# sex                  M      F       M       M       F       M
# length            0.56  0.565    0.59     0.6   0.625    0.71
# diameter          0.43   0.45    0.44   0.475   0.485   0.555
# height           0.155  0.165   0.135   0.205    0.15   0.195
# weight_whole    0.8675  0.887   0.966   1.176  1.0945  1.9485
# weight_shucked     0.4   0.37   0.439  0.5255   0.531  0.9455
# viscera          0.172  0.239  0.2145  0.2875   0.261  0.3765
# shell            0.229  0.249  0.2605   0.308   0.296   0.495
# n_rings              8     11      10       9      10      12
#
# [9 rows x 4177 columns]

# %% [markdown]
# DataFrames also provide several handy sorting methods

# %%
# default: ascending = True
df_abalone.sort_values(by=['n_rings', 'weight_whole']).head()
# Out:
#      sex  length  diameter  height  weight_whole  weight_shucked  viscera  \
# 236    I   0.075     0.055   0.010         0.002          0.0010   0.0005
# 719    I   0.150     0.100   0.025         0.015          0.0045   0.0040
# 238    I   0.110     0.090   0.030         0.008          0.0025   0.0020
# 237    I   0.130     0.100   0.030         0.013          0.0045   0.0030
# 1429   I   0.140     0.105   0.035         0.014          0.0055   0.0025
#
#        shell  n_rings
# 236   0.0015        1
# 719   0.0050        2
# 238   0.0030        3
# 237   0.0040        3
# 1429  0.0040        3

# %%
df_abalone.sort_values(by=['n_rings', 'weight_whole'], 
                      ascending=False)
# Out:
#      sex  length  diameter  height  weight_whole  weight_shucked  viscera  \
# 480    F   0.700     0.585   0.185        1.8075          0.7055   0.3215
# 2108   M   0.665     0.535   0.225        2.1835          0.7535   0.3910
# 2209   F   0.550     0.465   0.180        1.2125          0.3245   0.2050
# 294    M   0.600     0.495   0.195        1.0575          0.3840   0.1900
# 2201   F   0.645     0.490   0.215        1.4060          0.4265   0.2285
# 3149   F   0.700     0.540   0.215        1.9780          0.6675   0.3125
# 3280   M   0.690     0.540   0.185        1.6195          0.5330   0.3530
# 2334   F   0.800     0.630   0.195        2.5260          0.9330   0.5900
# 314    M   0.630     0.485   0.175        1.3000          0.4335   0.2945
# 313    F   0.620     0.470   0.200        1.2255          0.3810   0.2700
# 501    F   0.620     0.520   0.225        1.1835          0.3780   0.2700
# 2335   M   0.610     0.490   0.150        1.1030          0.4250   0.2025
# 2436   M   0.515     0.400   0.160        0.8175          0.2515   0.1560
# 678    F   0.450     0.380   0.165        0.8165          0.2500   0.1915
# 674    F   0.490     0.385   0.150        0.7865          0.2410   0.1400
# 2305   F   0.550     0.415   0.135        0.7750          0.3020   0.1790
# 275    M   0.655     0.540   0.215        1.8440          0.7425   0.3270
# 270    F   0.640     0.525   0.215        1.7790          0.4535   0.2855
# 232    M   0.625     0.505   0.215        1.4455          0.4960   0.2870
# 351    F   0.585     0.450   0.170        0.8685          0.3325   0.1635
# 433    M   0.545     0.420   0.140        0.7505          0.2475   0.1300
# 675    F   0.520     0.395   0.180        0.6400          0.1580   0.1100
# 478    M   0.735     0.590   0.225        1.7560          0.6370   0.3405
# 3151   F   0.665     0.500   0.175        1.7420          0.5950   0.3025
# 3930   F   0.670     0.535   0.185        1.5970          0.6275   0.3500
# 2199   F   0.680     0.550   0.200        1.5960          0.5250   0.4075
# 469    M   0.675     0.555   0.200        1.4385          0.5450   0.2665
# 181    M   0.640     0.510   0.175        1.3680          0.5150   0.2660
# 83     M   0.595     0.475   0.160        1.3175          0.4080   0.2340
# 2344   M   0.670     0.550   0.170        1.2470          0.4720   0.2455
# ...   ..     ...       ...     ...           ...             ...      ...
# 1053   I   0.185     0.130   0.045        0.0290          0.0120   0.0075
# 1986   I   0.135     0.130   0.040        0.0290          0.0125   0.0065
# 3600   I   0.175     0.125   0.040        0.0280          0.0095   0.0080
# 2305   F   0.550     0.415   0.135        0.7750          0.3020   0.1790
# 674    F   0.490     0.385   0.150        0.7865          0.2410   0.1400
# 678    F   0.450     0.380   0.165        0.8165          0.2500   0.1915
# 2436   M   0.515     0.400   0.160        0.8175          0.2515   0.1560
# 2335   M   0.610     0.490   0.150        1.1030          0.4250   0.2025
# 501    F   0.620     0.520   0.225        1.1835          0.3780   0.2700
# 313    F   0.620     0.470   0.200        1.2255          0.3810   0.2700
# 314    M   0.630     0.485   0.175        1.3000          0.4335   0.2945
# 2334   F   0.800     0.630   0.195        2.5260          0.9330   0.5900
# 3280   M   0.690     0.540   0.185        1.6195          0.5330   0.3530
# 3149   F   0.700     0.540   0.215        1.9780          0.6675   0.3125
# 2201   F   0.645     0.490   0.215        1.4060          0.4265   0.2285
# 294    M   0.600     0.495   0.195        1.0575          0.3840   0.1900
# 2209   F   0.550     0.465   0.180        1.2125          0.3245   0.2050
# 2108   M   0.665     0.535   0.225        2.1835          0.7535   0.3910
# 480    F   0.700     0.585   0.185        1.8075          0.7055   0.3215
#
#        shell  n_rings
# 236   0.0015        1
# 719   0.0050        2
# 238   0.0030        3
# 237   0.0040        3
# 1429  0.0040        3
# 526   0.0050        3
# 720   0.0050        3
# 3472  0.0140        3
# 306   0.0050        3
# 2371  0.0100        3
# 2115  0.0090        3
# 2711  0.0105        3
# 1054  0.0110        3
# 520   0.0100        3
# 3521  0.0125        3
# 3801  0.0140        3
# 894   0.0170        3
# 2114  0.0035        4
# 2169  0.0050        4
# 3899  0.0050        4
# 696   0.0050        4
# 3902  0.0050        4
# 694   0.0050        4
# 1987  0.0060        4
# 525   0.0050        4
# 3318  0.0080        4
# 718   0.0085        4
# 3600  0.0090        4
# 1053  0.0095        4
# 1986  0.0080        4
# ...      ...      ...
# 2344  0.4000       21
# 83    0.5800       21
# 181   0.5700       21
# 469   0.4650       21
# 2199  0.5850       21
# 3930  0.4700       21
# 3151  0.7250       21
# 478   0.5800       21
# 675   0.2450       22
# 433   0.2550       22
# 351   0.2700       22
# 232   0.4350       22
# 270   0.5500       22
# 275   0.5850       22
# 2305  0.2600       23
# 674   0.2400       23
# 678   0.2650       23
# 2436  0.3000       23
# 2335  0.3600       23
# 501   0.3950       23
# 313   0.4350       23
# 314   0.4600       23
# 2334  0.6200       23
# 3280  0.5550       24
# 3149  0.7100       24
# 2201  0.5100       25
# 294   0.3750       26
# 2209  0.5250       27
# 2108  0.8850       27
# 480   0.4750       29
#
# [4177 rows x 9 columns]

# %%
df_abalone.sort_values(by=['n_rings', 'weight_whole'], 
                      ascending=False).head()
# Out:
#      sex  length  diameter  height  weight_whole  weight_shucked  viscera  \
# 480    F   0.700     0.585   0.185        1.8075          0.7055   0.3215
# 2108   M   0.665     0.535   0.225        2.1835          0.7535   0.3910
# 2209   F   0.550     0.465   0.180        1.2125          0.3245   0.2050
# 294    M   0.600     0.495   0.195        1.0575          0.3840   0.1900
# 2201   F   0.645     0.490   0.215        1.4060          0.4265   0.2285
#
#       shell  n_rings
# 480   0.475       29
# 2108  0.885       27
# 2209  0.525       27
# 294   0.375       26
# 2201  0.510       25

# %% [markdown]
# ---
# Visualization
# ----

# %%
# The most common way of handling plotting in Jupyter Notebook
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df_abalone.length
# Out:
# 0       0.455
# 1       0.350
# 2       0.530
# 3       0.440
# 4       0.330
# 5       0.425
# 6       0.530
# 7       0.545
# 8       0.475
# 9       0.550
# 10      0.525
# 11      0.430
# 12      0.490
# 13      0.535
# 14      0.470
# 15      0.500
# 16      0.355
# 17      0.440
# 18      0.365
# 19      0.450
# 20      0.355
# 21      0.380
# 22      0.565
# 23      0.550
# 24      0.615
# 25      0.560
# 26      0.580
# 27      0.590
# 28      0.605
# 29      0.575
#         ...
# 4147    0.695
# 4148    0.770
# 4149    0.280
# 4150    0.330
# 4151    0.350
# 4152    0.370
# 4153    0.430
# 4154    0.435
# 4155    0.440
# 4156    0.475
# 4157    0.475
# 4158    0.480
# 4159    0.560
# 4160    0.585
# 4161    0.585
# 4162    0.385
# 4163    0.390
# 4164    0.390
# 4165    0.405
# 4166    0.475
# 4167    0.500
# 4168    0.515
# 4169    0.520
# 4170    0.550
# 4171    0.560
# 4172    0.565
# 4173    0.590
# 4174    0.600
# 4175    0.625
# 4176    0.710
# Name: length, Length: 4177, dtype: float64

# %%
# function ".hist()" for creating a histogramm!
df_abalone.length.hist()
# Out:
# <AxesSubplot:>

# %%
# number of unique values in a row
df_abalone.nunique()
# Out:
# sex                  3
# length             134
# diameter           111
# height              51
# weight_whole      2429
# weight_shucked    1515
# viscera            880
# shell              926
# n_rings             28
# dtype: int64

# %%
# working with the plot-functions (kind = bar) on the "n_rings"column!
df_abalone.n_rings.plot(kind='bar');

# %%
# gives direct value counts without grouping!
df_abalone.sex.value_counts()
# Out:
# M    1528
# I    1342
# F    1307
# Name: sex, dtype: int64

# %%
# Series example. One column of a df == series
L = [1,2,3]
pdL = pd.Series(L)
print(pdL)

pdL.plot(kind='bar');
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
# Excellent option for getting the frequency distribution of a value!
df_abalone.sex.value_counts().plot(kind='bar');

# %%
df_abalone.length.hist(); # Protip: Use semicolon to suppress ugly message

# %% [markdown]
# Let's get fancy!

# %%
from pandas.plotting import scatter_matrix

# %%
# passedm three colums to a scatter matrix and decided about diagonal content
scatter_matrix(df_abalone[["length", "diameter", "height"]],
              diagonal='hist');
# Out:
# /Users/david/opt/anaconda3/envs/nf/lib/python3.6/site-packages/pandas/plotting/_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Users/david/opt/anaconda3/envs/nf/lib/python3.6/site-packages/pandas/plotting/_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Users/david/opt/anaconda3/envs/nf/lib/python3.6/site-packages/pandas/plotting/_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Users/david/opt/anaconda3/envs/nf/lib/python3.6/site-packages/pandas/plotting/_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:

# %% [markdown]
# ----
# Selecting Columns
# ----
#
# **Rows go always first (0), columns follow (1)!!!**
#
# ![](https://i.stack.imgur.com/DL0iQ.jpg)

# %%
# Index of all column names
df_abalone.columns
# Out:
# Index(['sex', 'length', 'diameter', 'height', 'weight_whole', 'weight_shucked',
#        'viscera', 'shell', 'n_rings'],
#       dtype='object')

# %%
df_abalone['sex'].head()
# Out:
# 0    M
# 1    M
# 2    F
# 3    M
# 4    I
# Name: sex, dtype: object

# %%
df_abalone['length'].head()
# Out:
# 0    0.455
# 1    0.350
# 2    0.530
# 3    0.440
# 4    0.330
# Name: length, dtype: float64

# %% [markdown]
# Apply a function to every item in a column

# %%
# very useful for value manipulation!
df_abalone['length'].apply(lambda x: x + 1).head()

# %% [markdown]
# <br>
# <br>
# <br>
#
# ----
# ### Selecting Rows
#
# Square brackets select row subsets

# %%
# only one index value, the presentation of the columns isn't limited
df_abalone[:3]
# Out:
#   sex  length  diameter  height  weight_whole  weight_shucked  viscera  shell  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245   0.1010   0.15
# 1   M   0.350     0.265   0.090        0.2255          0.0995   0.0485   0.07
# 2   F   0.530     0.420   0.135        0.6770          0.2565   0.1415   0.21
#
#    n_rings
# 0       15
# 1        7
# 2        9

# %%
# mind the presentation of the multiple columns argument!!
df_abalone[100:104][["sex", "length"]]
# Out:
#     sex  length
# 100   I    0.36
# 101   M    0.55
# 102   M    0.53
# 103   M    0.53

# %% [markdown]
# ---
# ProTip: Just the sweet, sweet cell numbers

# %%
# value attribut // very important if a lib or method wants only to reveive data!
df_abalone[100:104].length.values
# Out:
# array([0.36, 0.55, 0.53, 0.53])

# %% [markdown]
# Often, statistical modeling libraries want only the data, typically as a numpy array.
# There will be an error if indexed data is passed.

# %% [markdown]
# ----
# group-by, the power feature of Pandas
# ----
#
# By “group by” we are referring to a process involving one or more of the following steps
#
# - __Splitting__ the data into groups based on some criteria
# - __Applying__ a function to each group independently
# - __Combining__ the results into a data structure
#
# [source](http://pandas.pydata.org/pandas-docs/stable/groupby.html)

# %%
# groupby does always include a function!
df2 = df_abalone.groupby('sex').mean()
df2
# Out:
#        length  diameter    height  weight_whole  weight_shucked   viscera  \
# sex
# F    0.579093  0.454732  0.158011      1.046532        0.446188  0.230689
# I    0.427746  0.326494  0.107996      0.431363        0.191035  0.092010
# M    0.561391  0.439287  0.151381      0.991459        0.432946  0.215545
#
#         shell    n_rings
# sex
# F    0.302010  11.129304
# I    0.128182   7.890462
# M    0.281969  10.705497

# %% [markdown]
# ---
# Summary
# -----
# - Pandas' DataFrame is the de facto data structure for Data Scientists
# - Get your data into a DataFrames ASAP
# - Use built-in methods to go fast!
#     - For example, use groupby to calculate aggregate statistics for categories

# %%
# Pandas is THE goto Tool for Data Scientis -> pandas first, get data into df!

# %% [markdown]
# <br>
# <br>
# <br>
#
# ----
# Further Study
# ----
#
# - [Book - Python for Data Analysis](http://shop.oreilly.com/product/0636920023784.do)
# - [Review and tour of pandas](http://manishamde.github.io/blog/2013/03/07/pandas-and-python-top-10/)
# - [Examples of further pandas functionality - Data Science for Political and Social Phenomena](http://chrisalbon.com)

# %% [markdown]
# <br>
# <br>
# <br>
#
# ----
